# %%
import requests
import pandas as pd
import time

# %%
url = "https://porn-xnxx-api.p.rapidapi.com/download"  # endpoint

headers = {
    "Content-Type": "application/json",
    "X-RapidAPI-Key": "3c871f290dmsh4eb994623544c0bp119979jsnf491f35ab6cd",
    "X-RapidAPI-Host": "porn-xnxx-api.p.rapidapi.com"
}

# %%
import pandas as pd

mock_data = [
    {
        "video_link": "sample_link_1",
        "status": "success",
        "title": "Sample Video 1",
        "download_url": "https://download-link-1"
    },
    {
        "video_link": "sample_link_2",
        "status": "failed",
        "title": None,
        "download_url": None
    }
]

df = pd.DataFrame(mock_data)
df
# Out:
#       video_link   status           title             download_url
# 0  sample_link_1  success  Sample Video 1  https://download-link-1
# 1  sample_link_2   failed            None                     None
